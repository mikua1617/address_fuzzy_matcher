# %%
import enchant
import jaro
import pandas as pd
import textdistance

df = pd.read_excel('../Samples.ods', sheet_name="US")
df
# Out:
#                 Street1        City1 State1 Country1  Pincode1  \
# 0    6649 N Blue Gum St  New Orleans     LA       US     70116
# 1    6650 N Blue Gum St  New Orleans     LA       US     70117
# 2    6651 N Blue Gum St  New Orleans     LA       US     70118
# 3    6652 N Blue Gum St  New Orleans     LA       US     70119
# 4    6653 N Blue Gum St  New Orleans     LA       US     70120
# ..                  ...          ...    ...      ...       ...
# 495     774 Leonis Blvd    Annandale     VA       US     22030
# 496     775 Leonis Blvd    Annandale     VA       US     22031
# 497     776 Leonis Blvd    Annandale     VA       US     22032
# 498     777 Leonis Blvd    Annandale     VA       US     22033
# 499     778 Leonis Blvd    Annandale     VA       US     22034
#
#                   Street2        City2 State2 Country2  Pincode2
# 0      6649 N Blue Gum St  New Orleans     LA       US     70116
# 1     4 B Blue Ridge Blvd     Brighton     MI       US     48116
# ...

# %% [markdown]
# determining the values of the parameters

# %%
string1 = "390007"
string2 = "390008"

# %% [markdown]
# the Levenshtein distance between<br>
# string1 and string2<br>
# print(1-textdistance.levenshtein.normalized_distance(string1, string2))<br>
# print(enchant.utils.levenshtein(string1, string2))

# %% [markdown]
# print(jaro.jaro_winkler_metric(string1, string2))

# %%
df["Pincode"] = df["Pincode"].apply(str)

# %%
print(df["Street"]+","+df["City"]+","+df["State"]+","+df["Country"]+","+df["Pincode"])

# %% [markdown]
# print(df.iloc[0]["Street"])
